# %%
import pandas as pd
import random

# %%
df = pd.read_csv('static/fakes.csv', sep='|')
#print(df.head())
wine_ix = random.randint(0,len(df))
wine_name = df.iloc[wine_ix,:]['name']
wine_description = df.iloc[wine_ix,:]['description']
wine_price = df.iloc[wine_ix,:]['price']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\david\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4380             try:
# -> 4381                 return libindex.get_value_box(s, key)
#    4382             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-8729c12955c2> in <module>
#       4 wine_name = df.iloc[wine_ix,:]['name']
#       5 wine_description = df.iloc[wine_ix,:]['description']
# ----> 6 wine_price = df.iloc[wine_ix,:]['price']
#
# c:\users\david\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# c:\users\david\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4387                     raise InvalidIndexError(key)
#    4388                 else:
# -> 4389                     raise e1
#    4390             except Exception:  # pragma: no cover
#    4391                 raise e1
#
# c:\users\david\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'

# %%
df
# Out:
#                                              Unnamed: 0  \
# 0     0|Joseph Carr Reveliste Cinsault 2013 |",,,,,,...
# 1                                     ,,,,,,,,,,,,,,,,,
# 2     Raisage a trip back in time at the Frank Famil...
# 3     1|Carol Shelton Roche TBredi 2016 |" ,,,,,,,,,...
# 4     Aromatics of this wine transporm nine expressi...
# 5     2|Finca Bolgheri Pinot Grigio 2018 |" This mak...
# 6     Sella of Côte de Beaune, juttery and open wine...
# 7     3|Domaine de Cristict Chardonnay 2016 |",,,,,,...
# 8     Digest boasts an intensity, or gift W   This w...
# 9     Very small amount of 118 is a strenger moon of...
# 10    Dark ruby-red in color, this wine offers well ...
# 11    Just expressions of Champagne's best gravity, ...
# 12    4|Domaine Dujac Fils andamp; Pere Chambolle Ro...
# 13    Red Diamond slo and growers and shale ,,,,,,,,...
# 14                                    ,,,,,,,,,,,,,,,,,
# 15                                    ,,,,,,,,,,,,,,,,,
# 16    Blackbirds is on the eastern flal Bouchers, th...
# 17    5|Tenuta Sant'Antonio Barolo Cannubi (1.5 Lite...
# 18    Pale rich and tannin and dark black fruits wit...
# 19    6|Cavit Alta Luna Pinot Noir 2016 |" For more ...
# 20    Deep and rich with a long and floral finish wi...
# 21    7|Philipponnat Royale Reserve 2007 |" ,,,,,,,,...
# 22    Bottle is perfect for paired with a hint of sp...
# 23    A beautiful dark ruby color with intense ripe ...
# 24    This organically contains represent 20+32 ,,,,...
# 25                                    ,,,,,,,,,,,,,,,,,
# 26    Powerful and longer in nick's oldiva displays ...
# 27    8|Bodegas Lan Culmenet Chardonnay 2017 |",,,,,...
# 28    For more than a century, has been natisned, Di...
# 29    From a modest hourd, ton make Hiddenp 222,6,30...
# ...                                                 ...
# 3751                                  ,,,,,,,,,,,,,,,,,
# 3752  This champagne is a red clear, dry and electri...
# 3753  Deliciously savory, with Sauvignon Blanc," and...
# 3754  1264|Pedralongal Rose 2017 |" This Cabernet Sa...
# 3755  Pale pink robe, this wine boasts a robust tann...
# 3756  1265|Gamble Family Vineyards Malbec 2016 |" Ca...
# 3757  Light gold, and copleaubly, but when to our Ca...
# 3758  A vibrant ruby red over time in the mouth, sof...
# 3759  In 1980," Estate Port winery building and cont...
# 3760                                               1266
# 3761  1267|Titus Cabernet Sauvignon 2016 |" Spenning...
# 3762  FIST, these walked along the boldest vines," S...
# 3763  1268|Domaine D'Inclier Bendrone Barbera D'Aste...
# 3764                                  ,,,,,,,,,,,,,,,,,
# 3765  Black berries and blackcurrant makes the Chris...
# 3766  1269|J. Lohr Wildfles Estate Semillon Sancerre...
# 3767  Soaring comes from multiple vineyard shows fru...
# 3768                                               1270
# 3769  1271|Brick Barn Pinot Noir 2016 |" On a windy ...
# 3770  Another single vineyard Pinot Noir they were o...
# 3771  An exquisitely by the minerality and followed ...
# 3772  1272|Masi Rosa Pinot Noir 2015 |" Solid tannin...
# 3773  Dominio Burgundian winemakers deliver it too m...
# 3774  The most was instrumental in the Lade Counters...
# 3775  1273|Andrew Rich Cru 2016 |" They made trisple...
# 3776  Medium to full-bodied and supple with velvety,...
# 3777  1274|Chateau de Lagrezs 2012 |" Only one of th...
# 3778  On the nose their wines Syrah is pleasing, rip...
# 3779                                  ,,,,,,,,,,,,,,,,,
# 3780  Dark and brown spices  On the palate, lingers ...
#
#                                     name  \
# 0                                    NaN
# 1                                    NaN
# 2                      44",,,,,,,,,,,,,,
# 3                                    NaN
# 4                            40",,,,,,,,
# 5                                    NaN
# 6                     51",,,,,,,,,,,,,,,
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                    42",,,,,,,,,,,,,,,
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                      40",,,,,,,,,,,,,
# 17                                   NaN
# 18                           94",,,,,,,,
# 19                                   NaN
# 20                   37",,,,,,,,,,,,,,,,
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                     70",,,,,,,,,,,,,,
# 27                                   NaN
# 28                                   NaN
# 29                      35",,,,,,,,,,,,,
# ...                                  ...
# 3751                                 NaN
# 3752                                 NaN
# 3753                  90",,,,,,,,,,,,,,,
# 3754                                 NaN
# 3755                   30",,,,,,,,,,,,,,
# 3756                                 NaN
# 3757                                 NaN
# 3758                                 NaN
# 3759                 48",,,,,,,,,,,,,,,,
# 3760  Clockwort Cabernet Sauvignon 2014
# 3761                                 NaN
# 3762                  54",,,,,,,,,,,,,,,
# 3763                                 NaN
# 3764                                 NaN
# 3765                   25",,,,,,,,,,,,,,
# 3766                                 NaN
# 3767                                 NaN
# 3768           Bouchaud Chardonnay 2016
# 3769                                 NaN
# 3770                                 NaN
# 3771                   40",,,,,,,,,,,,,,
# 3772                                 NaN
# 3773                                 NaN
# 3774                           75",,,,,,
# 3775                                 NaN
# 3776                209",,,,,,,,,,,,,,,,
# 3777                                 NaN
# 3778                                 NaN
# 3779                                 NaN
# 3780                  46",,,,,,,,,,,,,,,
#
#                                             description price,,,,,,,,,,,,,,,,,
# 0                                                   NaN                    NaN
# 1                                                   NaN                    NaN
# 2                                                   NaN                    NaN
# 3                                                   NaN                    NaN
# 4                                                   NaN                    NaN
# 5                                                   NaN                    NaN
# 6                                                   NaN                    NaN
# 7                                                   NaN                    NaN
# 8                                                   NaN                    NaN
# 9                                                   NaN                    NaN
# 10                                                  NaN                    NaN
# 11                                                  NaN                    NaN
# 12                                                  NaN                    NaN
# 13                                                  NaN                    NaN
# 14                                                  NaN                    NaN
# 15                                                  NaN                    NaN
# 16                                                  NaN                    NaN
# 17                                                  NaN                    NaN
# 18                                                  NaN                    NaN
# 19                                                  NaN                    NaN
# 20                                                  NaN                    NaN
# 21                                                  NaN                    NaN
# 22                                                  NaN                    NaN
# 23                                                  NaN                    NaN
# 24                                                  NaN                    NaN
# 25                                                  NaN                    NaN
# 26                                                  NaN                    NaN
# 27                                                  NaN                    NaN
# 28                                                  NaN                    NaN
# 29                                                  NaN                    NaN
# ...                                                 ...                    ...
# 3751                                                NaN                    NaN
# 3752                                                NaN                    NaN
# 3753                                                NaN                    NaN
# 3754                                                NaN                    NaN
# 3755                                                NaN                    NaN
# 3756                                                NaN                    NaN
# 3757                                                NaN                    NaN
# 3758                                                NaN                    NaN
# 3759                                                NaN                    NaN
# 3760   As (limestone, canto later, similarities indi...           27,,,,,,,,,,
# 3761                                                NaN                    NaN
# 3762                                                NaN                    NaN
# 3763                                                NaN                    NaN
# 3764                                                NaN                    NaN
# 3765                                                NaN                    NaN
# 3766                                                NaN                    NaN
# 3767                                                NaN                    NaN
# 3768   Enveloping green apples and fresh raspberry j...     61,,,,,,,,,,,,,,,,
# 3769                                                NaN                    NaN
# 3770                                                NaN                    NaN
# 3771                                                NaN                    NaN
# 3772                                                NaN                    NaN
# 3773                                                NaN                    NaN
# 3774                                                NaN                    NaN
# 3775                                                NaN                    NaN
# 3776                                                NaN                    NaN
# 3777                                                NaN                    NaN
# 3778                                                NaN                    NaN
# 3779                                                NaN                    NaN
# 3780                                                NaN                    NaN
#
# [3781 rows x 4 columns]
